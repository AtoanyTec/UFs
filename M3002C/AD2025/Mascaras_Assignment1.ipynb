# %% [markdown]
# # **Ejercicio: Optimización de Almacén**

# %% [markdown]
# ## **1. Carga de Dataset**

# %% [markdown]
# 1. Carga el archivo 'mascaras.csv' al cuaderno

# %% [markdown]
# ## **2. Análisis Exploratorio**

# %% [markdown]
# **1. Codificar la columna categoria**

# %%
from sklearn.preprocessing import LabelEncoder

#Completa el código, reemlaza None por tu respuesta
le = LabelEncoder()
df[None] = le.fit_transform(df[None])
df.head(3)

# %% [markdown]
# **2. Realizar un análisis exploratorio  de los datos**
#   - **Verificar el tipo de datos de cada columna**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **Verificar si hay valores nulos en el dataset**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   - **Verificar si contiene datoss duplicados**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   - **Eliminar posibles variables no relevantes**

# %% [markdown]
# - **Crear un gráfico en donde se observe las ventas en 2022 y 2023 por categoria**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   - **Cerar un grafico donde se observe la máscara mas vendida en 2022 y 2023, respectivamente**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#   - **Crar un grafico de barras donde se observe las ventas del 2022 y del 2023, respectivamente**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **3. Calcular la eficiencia**

# %% [markdown]
# **1. Calcular la eficiencia en ventas/metros de las ventas de 2022 y 2023, respectivamente. Utiliz la fórmula** `ventas_2022/distancia_esperada`

# %% [markdown]
# **2. Calcula la mejora en eficiencia entre 2022 y 2023. utiliza la fórmula**
#
# `mejora = ((eficiencia_2023 - eficiencia_2022) / eficiencia_2022) * 100`

# %% [markdown]
# **3. Calcular un score de tendencias**
#
# Utiliza la fórmula `score = tendencia_busquedas*0.3 + (redes_sociaes/50000)*0.7`
